# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

initial_state = list(map(int, input("Enter initial state as 8 space-separated integers: ").split()))
solution_state, solution_cost = hillClimbing(initial_state)

print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 8 space-separated integers: 1 3 2 5 4 7 6 8
#
# Iteration 0
# Current State: [1, 3, 2, 5, 4, 7, 6, 8], Cost: 10
# Neighbour: [3, 1, 2, 5, 4, 7, 6, 8], Cost: 9
# Neighbour: [2, 3, 1, 5, 4, 7, 6, 8], Cost: 9
# Neighbour: [5, 3, 2, 1, 4, 7, 6, 8], Cost: 8
# Neighbour: [4, 3, 2, 5, 1, 7, 6, 8], Cost: 8
# Neighbour: [7, 3, 2, 5, 4, 1, 6, 8], Cost: 6
# Neighbour: [6, 3, 2, 5, 4, 7, 1, 8], Cost: 6
# Neighbour: [8, 3, 2, 5, 4, 7, 6, 1], Cost: 14
# Neighbour: [1, 2, 3, 5, 4, 7, 6, 8], Cost: 10
# Neighbour: [1, 5, 2, 3, 4, 7, 6, 8], Cost: 9
# Neighbour: [1, 4, 2, 5, 3, 7, 6, 8], Cost: 4
# Neighbour: [1, 7, 2, 5, 4, 3, 6, 8], Cost: 10
# Neighbour: [1, 6, 2, 5, 4, 7, 3, 8], Cost: 4
# Neighbour: [1, 8, 2, 5, 4, 7, 6, 3], Cost: 6
# Neighbour: [1, 3, 5, 2, 4, 7, 6, 8], Cost: 4
# Neighbour: [1, 3, 4, 5, 2, 7, 6, 8], Cost: 9
# Neighbour: [1, 3, 7, 5, 4, 2, 6, 8], Cost: 4
# Neighbour: [1, 3, 6, 5, 4, 7, 2, 8], Cost: 10
# Neighbour: [1, 3, 8, 5, 4, 7, 6, 2], Cost: 6
# Neighbour: [1, 3, 2, 4, 5, 7, 6, 8], Cost: 10
# Neighbour: [1, 3, 2, 7, 4, 5, 6, 8], Cost: 9
# Neighbour: [1, 3, 2, 6, 4, 7, 5, 8], Cost: 4
# Neighbour: [1, 3, 2, 8, 4, 7, 6, 5], Cost: 8
# Neighbour: [1, 3, 2, 5, 7, 4, 6, 8], Cost: 4
# Neighbour: [1, 3, 2, 5, 6, 7, 4, 8], Cost: 9
# Neighbour: [1, 3, 2, 5, 8, 7, 6, 4], Cost: 8
# Neighbour: [1, 3, 2, 5, 4, 6, 7, 8], Cost: 10
# Neighbour: [1, 3, 2, 5, 4, 8, 6, 7], Cost: 9
# Neighbour: [1, 3, 2, 5, 4, 7, 8, 6], Cost: 9
#
# Iteration 1
# Current State: [1, 4, 2, 5, 3, 7, 6, 8], Cost: 4
# Neighbour: [4, 1, 2, 5, 3, 7, 6, 8], Cost: 6
# Neighbour: [2, 4, 1, 5, 3, 7, 6, 8], Cost: 5
# Neighbour: [5, 4, 2, 1, 3, 7, 6, 8], Cost: 4
# Neighbour: [3, 4, 2, 5, 1, 7, 6, 8], Cost: 5
# Neighbour: [7, 4, 2, 5, 3, 1, 6, 8], Cost: 2
# Neighbour: [6, 4, 2, 5, 3, 7, 1, 8], Cost: 2
# Neighbour: [8, 4, 2, 5, 3, 7, 6, 1], Cost: 6
# Neighbour: [1, 2, 4, 5, 3, 7, 6, 8], Cost: 7
# Neighbour: [1, 5, 2, 4, 3, 7, 6, 8], Cost: 6
# Neighbour: [1, 3, 2, 5, 4, 7, 6, 8], Cost: 10
# Neighbour: [1, 7, 2, 5, 3, 4, 6, 8], Cost: 4
# Neighbour: [1, 6, 2, 5, 3, 7, 4, 8], Cost: 3
# Neighbour: [1, 8, 2, 5, 3, 7, 6, 4], Cost: 3
# Neighbour: [1, 4, 5, 2, 3, 7, 6, 8], Cost: 6
# Neighbour: [1, 4, 3, 5, 2, 7, 6, 8], Cost: 6
# Neighbour: [1, 4, 7, 5, 3, 2, 6, 8], Cost: 2
# Neighbour: [1, 4, 6, 5, 3, 7, 2, 8], Cost: 5
# Neighbour: [1, 4, 8, 5, 3, 7, 6, 2], Cost: 2
# Neighbour: [1, 4, 2, 3, 5, 7, 6, 8], Cost: 7
# Neighbour: [1, 4, 2, 7, 3, 5, 6, 8], Cost: 5
# Neighbour: [1, 4, 2, 6, 3, 7, 5, 8], Cost: 3
# Neighbour: [1, 4, 2, 8, 3, 7, 6, 5], Cost: 4
# Neighbour: [1, 4, 2, 5, 7, 3, 6, 8], Cost: 4
# Neighbour: [1, 4, 2, 5, 6, 7, 3, 8], Cost: 4
# Neighbour: [1, 4, 2, 5, 8, 7, 6, 3], Cost: 5
# Neighbour: [1, 4, 2, 5, 3, 6, 7, 8], Cost: 6
# Neighbour: [1, 4, 2, 5, 3, 8, 6, 7], Cost: 4
# Neighbour: [1, 4, 2, 5, 3, 7, 8, 6], Cost: 4
#
# Iteration 2
# Current State: [7, 4, 2, 5, 3, 1, 6, 8], Cost: 2
# Neighbour: [4, 7, 2, 5, 3, 1, 6, 8], Cost: 3
# Neighbour: [2, 4, 7, 5, 3, 1, 6, 8], Cost: 1
# Neighbour: [5, 4, 2, 7, 3, 1, 6, 8], Cost: 2
# Neighbour: [3, 4, 2, 5, 7, 1, 6, 8], Cost: 4
# Neighbour: [1, 4, 2, 5, 3, 7, 6, 8], Cost: 4
# Neighbour: [6, 4, 2, 5, 3, 1, 7, 8], Cost: 2
# Neighbour: [8, 4, 2, 5, 3, 1, 6, 7], Cost: 4
# Neighbour: [7, 2, 4, 5, 3, 1, 6, 8], Cost: 4
# Neighbour: [7, 5, 2, 4, 3, 1, 6, 8], Cost: 6
# Neighbour: [7, 3, 2, 5, 4, 1, 6, 8], Cost: 6
# Neighbour: [7, 1, 2, 5, 3, 4, 6, 8], Cost: 5
# Neighbour: [7, 6, 2, 5, 3, 1, 4, 8], Cost: 3
# Neighbour: [7, 8, 2, 5, 3, 1, 6, 4], Cost: 3
# Neighbour: [7, 4, 5, 2, 3, 1, 6, 8], Cost: 6
# Neighbour: [7, 4, 3, 5, 2, 1, 6, 8], Cost: 3
# Neighbour: [7, 4, 1, 5, 3, 2, 6, 8], Cost: 4
# Neighbour: [7, 4, 6, 5, 3, 1, 2, 8], Cost: 5
# Neighbour: [7, 4, 8, 5, 3, 1, 6, 2], Cost: 1
# Neighbour: [7, 4, 2, 3, 5, 1, 6, 8], Cost: 5
# Neighbour: [7, 4, 2, 1, 3, 5, 6, 8], Cost: 5
# Neighbour: [7, 4, 2, 6, 3, 1, 5, 8], Cost: 3
# Neighbour: [7, 4, 2, 8, 3, 1, 6, 5], Cost: 3
# Neighbour: [7, 4, 2, 5, 1, 3, 6, 8], Cost: 3
# Neighbour: [7, 4, 2, 5, 6, 1, 3, 8], Cost: 1
# Neighbour: [7, 4, 2, 5, 8, 1, 6, 3], Cost: 3
# Neighbour: [7, 4, 2, 5, 3, 6, 1, 8], Cost: 4
# Neighbour: [7, 4, 2, 5, 3, 8, 6, 1], Cost: 4
# Neighbour: [7, 4, 2, 5, 3, 1, 8, 6], Cost: 3
#
# Iteration 3
# Current State: [2, 4, 7, 5, 3, 1, 6, 8], Cost: 1
# Neighbour: [4, 2, 7, 5, 3, 1, 6, 8], Cost: 1
# Neighbour: [7, 4, 2, 5, 3, 1, 6, 8], Cost: 2
# Neighbour: [5, 4, 7, 2, 3, 1, 6, 8], Cost: 5
# Neighbour: [3, 4, 7, 5, 2, 1, 6, 8], Cost: 2
# Neighbour: [1, 4, 7, 5, 3, 2, 6, 8], Cost: 2
# Neighbour: [6, 4, 7, 5, 3, 1, 2, 8], Cost: 3
# Neighbour: [8, 4, 7, 5, 3, 1, 6, 2], Cost: 2
# Neighbour: [2, 7, 4, 5, 3, 1, 6, 8], Cost: 5
# Neighbour: [2, 5, 7, 4, 3, 1, 6, 8], Cost: 3
# Neighbour: [2, 3, 7, 5, 4, 1, 6, 8], Cost: 5
# Neighbour: [2, 1, 7, 5, 3, 4, 6, 8], Cost: 5
# Neighbour: [2, 6, 7, 5, 3, 1, 4, 8], Cost: 3
# Neighbour: [2, 8, 7, 5, 3, 1, 6, 4], Cost: 2
# Neighbour: [2, 4, 5, 7, 3, 1, 6, 8], Cost: 2
# Neighbour: [2, 4, 3, 5, 7, 1, 6, 8], Cost: 4
# Neighbour: [2, 4, 1, 5, 3, 7, 6, 8], Cost: 5
# Neighbour: [2, 4, 6, 5, 3, 1, 7, 8], Cost: 3
# Neighbour: [2, 4, 8, 5, 3, 1, 6, 7], Cost: 2
# Neighbour: [2, 4, 7, 3, 5, 1, 6, 8], Cost: 4
# Neighbour: [2, 4, 7, 1, 3, 5, 6, 8], Cost: 1
# Neighbour: [2, 4, 7, 6, 3, 1, 5, 8], Cost: 3
# Neighbour: [2, 4, 7, 8, 3, 1, 6, 5], Cost: 2
# Neighbour: [2, 4, 7, 5, 1, 3, 6, 8], Cost: 3
# Neighbour: [2, 4, 7, 5, 6, 1, 3, 8], Cost: 4
# Neighbour: [2, 4, 7, 5, 8, 1, 6, 3], Cost: 3
# Neighbour: [2, 4, 7, 5, 3, 6, 1, 8], Cost: 3
# Neighbour: [2, 4, 7, 5, 3, 8, 6, 1], Cost: 3
# Neighbour: [2, 4, 7, 5, 3, 1, 8, 6], Cost: 4
#
# Final Results
# Initial State: [1, 3, 2, 5, 4, 7, 6, 8]
# Final State (Solution): [2, 4, 7, 5, 3, 1, 6, 8]
# Final Cost (Attacking Pairs): 1
# Local optimum reached, but no solution.

# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

initial_state = list(map(int, input("Enter initial state as 8 space-separated integers: ").split()))
solution_state, solution_cost = hillClimbing(initial_state)

print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 8 space-separated integers: 1 5 6 8 3 7 2 4
#
# Iteration 0
# Current State: [1, 5, 6, 8, 3, 7, 2, 4], Cost: 3
# Neighbour: [5, 1, 6, 8, 3, 7, 2, 4], Cost: 3
# Neighbour: [6, 5, 1, 8, 3, 7, 2, 4], Cost: 3
# Neighbour: [8, 5, 6, 1, 3, 7, 2, 4], Cost: 4
# Neighbour: [3, 5, 6, 8, 1, 7, 2, 4], Cost: 4
# Neighbour: [7, 5, 6, 8, 3, 1, 2, 4], Cost: 6
# Neighbour: [2, 5, 6, 8, 3, 7, 1, 4], Cost: 4
# Neighbour: [4, 5, 6, 8, 3, 7, 2, 1], Cost: 6
# Neighbour: [1, 6, 5, 8, 3, 7, 2, 4], Cost: 5
# Neighbour: [1, 8, 6, 5, 3, 7, 2, 4], Cost: 4
# Neighbour: [1, 3, 6, 8, 5, 7, 2, 4], Cost: 4
# Neighbour: [1, 7, 6, 8, 3, 5, 2, 4], Cost: 4
# Neighbour: [1, 2, 6, 8, 3, 7, 5, 4], Cost: 5
# Neighbour: [1, 4, 6, 8, 3, 7, 2, 5], Cost: 2
# Neighbour: [1, 5, 8, 6, 3, 7, 2, 4], Cost: 0
# Neighbour: [1, 5, 3, 8, 6, 7, 2, 4], Cost: 3
# Neighbour: [1, 5, 7, 8, 3, 6, 2, 4], Cost: 5
# Neighbour: [1, 5, 2, 8, 3, 7, 6, 4], Cost: 3
# Neighbour: [1, 5, 4, 8, 3, 7, 2, 6], Cost: 3
# Neighbour: [1, 5, 6, 3, 8, 7, 2, 4], Cost: 6
# Neighbour: [1, 5, 6, 7, 3, 8, 2, 4], Cost: 4
# Neighbour: [1, 5, 6, 2, 3, 7, 8, 4], Cost: 3
# Neighbour: [1, 5, 6, 4, 3, 7, 2, 8], Cost: 6
# Neighbour: [1, 5, 6, 8, 7, 3, 2, 4], Cost: 7
# Neighbour: [1, 5, 6, 8, 2, 7, 3, 4], Cost: 4
# Neighbour: [1, 5, 6, 8, 4, 7, 2, 3], Cost: 5
# Neighbour: [1, 5, 6, 8, 3, 2, 7, 4], Cost: 5
# Neighbour: [1, 5, 6, 8, 3, 4, 2, 7], Cost: 3
# Neighbour: [1, 5, 6, 8, 3, 7, 4, 2], Cost: 1
#
# Final Results
# Initial State: [1, 5, 6, 8, 3, 7, 2, 4]
# Final State (Solution): [1, 5, 8, 6, 3, 7, 2, 4]
# Final Cost (Attacking Pairs): 0
# Solution found!
